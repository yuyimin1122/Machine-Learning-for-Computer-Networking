# %%
import pandas as pd

# %%
from datetime import datetime, timezone
# Allow us to load modules from the parent directory
import sys
sys.path.append(r'C:\Users\HiWin10\Desktop\winter_vacation\ml-networking-master\lib') 
from parse_pcap import pcap_to_pandas, send_rates

# %%
pcap = pcap_to_pandas(r'C:\Users\HiWin10\Desktop\test.pcap')

pcap.head(10)
# Out:
#              datetime dns_query dns_resp         ip_dst    ip_dst_int  \
# 0 2021-02-22 20:52:41      None     None  192.168.0.107  3.232236e+09
# 1 2021-02-22 20:52:41      None     None  20.194.38.240  3.482683e+08
# 2 2021-02-22 20:52:41      None     None  192.168.0.107  3.232236e+09
# 3 2021-02-22 20:52:41      None     None  20.194.38.240  3.482683e+08
# 4 2021-02-22 20:52:41      None     None  192.168.0.107  3.232236e+09
# 5 2021-02-22 20:52:41      None     None  20.194.38.240  3.482683e+08
# 6 2021-02-22 20:52:41      None     None  192.168.0.107  3.232236e+09
# 7 2021-02-22 20:52:41      None     None  20.194.38.240  3.482683e+08
# 8 2021-02-22 20:52:41      None     None  192.168.0.107  3.232236e+09
# 9 2021-02-22 20:52:41      None     None  20.194.38.240  3.482683e+08
#
#           ip_src    ip_src_int  is_dns  length            mac_dst  \
# 0  20.194.38.240  3.482683e+08   False    1506  80:c5:f2:f9:c7:5d
# ...

# %%
local_ip = '192.168.0.107'

# %%
pcap[pcap['ip_src'] == local_ip]['length'].mean()
# Out:
# 71.94645941278065

# %%
pcap[pcap['ip_src'] == local_ip]['length'].max()
# Out:
# 119

# %%
pcap[pcap['ip_src'] == local_ip]['length'].min()
# Out:
# 54

# %%
pcap[pcap['ip_src'] == local_ip]['length'].median()
# Out:
# 74.0
